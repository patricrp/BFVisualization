# %% [markdown]
# ## Tokens setup

# %%
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
consumer_key = os.getenv("API_KEY_C")
consumer_secret = os.getenv("API_SECRET_KEY_C")
access_token = os.getenv("ACCESS_TOKEN_C")
access_token_secret = os.getenv("ACCESS_TOKEN_SECRET_C")

# %% [markdown]
# ## Authentication

# %%
import tweepy
import json
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %% [markdown]
# ## API creation

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
query = 'CyberMonday'
tweets = tweepy.Cursor(api.search,
                       q=query,
                       lang="es",
                       geo='40.416775,-3.703790, 510',
                       result_type='mixed').items(10)

# %%
data = [[query, tweet.id, tweet.created_at, tweet.user.location, tweet.user.screen_name, tweet.text, tweet.entities['hashtags'], tweet.favorite_count, tweet.retweet_count, tweet.entities['urls'], tweet.user.followers_count] for tweet in tweets]

df = pd.DataFrame(data=data, columns=['query','id', 'date', 'location', 'user', 'text', 'hashtags', 'favorites', 'retweets', 'urls', 'followers'])

# %%
df
# Out:
#          query                   id                date              location  \
# 0  CyberMonday  1331236744767926275 2020-11-24 14:02:27    Guayaquil, Ecuador
# 1  CyberMonday  1332009994905071618 2020-11-26 17:15:04                España
# 2  CyberMonday  1331855304699604992 2020-11-26 07:00:23                España
# 3  CyberMonday  1333126635239956481 2020-11-29 19:12:12
# 4  CyberMonday  1333126089590321153 2020-11-29 19:10:02             El Averno
# 5  CyberMonday  1333125983549972490 2020-11-29 19:09:37
# 6  CyberMonday  1333125949454430210 2020-11-29 19:09:29              Móstoles
# 7  CyberMonday  1333125743287611400 2020-11-29 19:08:40              Móstoles
# 8  CyberMonday  1333124721702002690 2020-11-29 19:04:36
# 9  CyberMonday  1333124704400519168 2020-11-29 19:04:32  Pueblo Nuevo, Madrid
#
#               user                                               text  \
# 0    eluniversocom  Cámara de Comercio de Guayaquil anuncia cuatro...
# 1           INCIBE  No seas tu el chollo de los ciberdelincuentes ...
# 2           INCIBE  ¡Buenos días! #BlackFriday, #CyberMonday, #Nav...
# 3         HogarCom  Las fechas navideñas ya están aquí, y con ella...
# 4  InformDelAverno  RT @0xWORD: Como todos los años, desde hoy a l...
# 5  VirginiaParraC2  RT @liverpoolmexico: Descubre los beneficios d...
# 6      chemaalonso  RT @0xWORD: Como todos los años, desde hoy a l...
# 7           0xWORD  Como todos los años, desde hoy a las 00:00:00 ...
# 8       Loliflor71  RT @SantanderMx: ¡Ya viene el #Cybermonday! Re...
# 9          PipoBB8  ¡Tu Monsieur Cuisine al -50%!\n¡El mejor hacie...
#
#                                             hashtags  favorites  retweets  \
# 0                                                 []         23        17
# 1  [{'text': 'BlackFriday', 'indices': [51, 63]},...         22        20
# 2  [{'text': 'BlackFriday', 'indices': [14, 26]},...         22        21
# 3  [{'text': 'ofertas', 'indices': [52, 60]}, {'t...          0         0
# 4                                                 []          0         2
# 5     [{'text': 'CyberMonday', 'indices': [53, 65]}]          0         2
# 6                                                 []          0         2
# 7                                                 []          3         2
# 8     [{'text': 'Cybermonday', 'indices': [30, 42]}]          0       106
# 9     [{'text': 'CyberMonday', 'indices': [66, 78]}]          0         0
#
#                                                 urls  followers
# 0  [{'url': 'https://t.co/m07aK2u47s', 'expanded_...    2208088
# 1  [{'url': 'https://t.co/T2FzUbDGca', 'expanded_...      61206
# 2  [{'url': 'https://t.co/nOUN4HJqfx', 'expanded_...      61206
# 3  [{'url': 'https://t.co/MnHjVJEO3I', 'expanded_...        358
# 4                                                 []        104
# 5                                                 []        135
# 6                                                 []     143990
# 7  [{'url': 'https://t.co/Vl2nr51FF3', 'expanded_...      14319
# 8                                                 []        124
# 9                                                 []       2738

# %%
count = 1
while count >= 1:
    tweets = tweepy.Cursor(api.search,
                           q=query,
                           lang='es',
                           geo='40.416775,-3.703790, 510',
                           result_type='mixed',
                           max_id=df.id.max()).items(1500)
    data = [[query, tweet.id, tweet.created_at, tweet.user.location, tweet.user.screen_name, tweet.text, tweet.entities['hashtags'], tweet.favorite_count, tweet.retweet_count, tweet.entities['urls'], tweet.user.followers_count] for tweet in tweets] 
    df2 = pd.DataFrame(data=data, columns=['query','id', 'date', 'location', 'user', 'text', 'hashtags', 'favorites', 'retweets', 'url', 'followers'])
    df = df.append(df2, sort=True)
    count += 1
    print('Updating your dataframe. Adding 1500 to the dataframe')
    print(df.shape)
    print('Id max', df.id.max())
# Out:
# Updating your dataframe. Adding 1500 to the dataframe
# (1510, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 763
# Updating your dataframe. Adding 1500 to the dataframe
# (3010, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (4510, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 783
# Updating your dataframe. Adding 1500 to the dataframe
# (6010, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (7510, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 782
# Updating your dataframe. Adding 1500 to the dataframe
# (9010, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (10510, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 782
# Updating your dataframe. Adding 1500 to the dataframe
# (12010, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 782
# Updating your dataframe. Adding 1500 to the dataframe
# (13510, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (15010, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 782
# Updating your dataframe. Adding 1500 to the dataframe
# (16510, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (18010, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 778
# Updating your dataframe. Adding 1500 to the dataframe
# (19510, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (21010, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 781
# Updating your dataframe. Adding 1500 to the dataframe
# (22510, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (24010, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 782
# Updating your dataframe. Adding 1500 to the dataframe
# (25510, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 781
# Updating your dataframe. Adding 1500 to the dataframe
# (27010, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (28510, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 782
# Updating your dataframe. Adding 1500 to the dataframe
# (30010, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (31510, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 782
# Updating your dataframe. Adding 1500 to the dataframe
# (33010, 12)
# Id max 1333126635239956481
# Updating your dataframe. Adding 1500 to the dataframe
# (34510, 12)
# Id max 1333126635239956481
# Rate limit reached. Sleeping for: 781
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f6eceb410567> in <module>
#       7                            result_type='mixed',
#       8                            max_id=df.id.max()).items(1500)
# ----> 9     data = [[query, tweet.id, tweet.created_at, tweet.user.location, tweet.user.screen_name, tweet.text, tweet.entities['hashtags'], tweet.favorite_count, tweet.retweet_count, tweet.entities['urls'], tweet.user.followers_count] for tweet in tweets]
#      10     df2 = pd.DataFrame(data=data, columns=['query','id', 'date', 'location', 'user', 'text', 'hashtags', 'favorites', 'retweets', 'url', 'followers'])
#      11     df = df.append(df2, sort=True)
#
# <ipython-input-7-f6eceb410567> in <listcomp>(.0)
#       7                            result_type='mixed',
#       8                            max_id=df.id.max()).items(1500)
# ----> 9     data = [[query, tweet.id, tweet.created_at, tweet.user.location, tweet.user.screen_name, tweet.text, tweet.entities['hashtags'], tweet.favorite_count, tweet.retweet_count, tweet.entities['urls'], tweet.user.followers_count] for tweet in tweets]
#      10     df2 = pd.DataFrame(data=data, columns=['query','id', 'date', 'location', 'user', 'text', 'hashtags', 'favorites', 'retweets', 'url', 'followers'])
#      11     df = df.append(df2, sort=True)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     160                                     if self.wait_on_rate_limit_notify:
#     161                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 162                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     163
#     164                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %%
df.to_csv('../output/CyberMonday.csv')

# %%
#Continuación

# %%
df = pd.read_csv('../output/CyberMonday.csv')
df
# Out:
#        Unnamed: 0                 date  favorites  followers  \
# 0               0  2020-11-24 14:02:27         23    2208088
# 1               1  2020-11-26 17:15:04         22      61206
# 2               2  2020-11-26 07:00:23         22      61206
# 3               3  2020-11-29 19:12:12          0        358
# 4               4  2020-11-29 19:10:02          0        104
# ...           ...                  ...        ...        ...
# 34505        1495  2020-11-26 09:28:13          3     154743
# 34506        1496  2020-11-26 09:27:28          0        314
# 34507        1497  2020-11-26 09:22:52          0        167
# 34508        1498  2020-11-26 09:21:29          1        303
# 34509        1499  2020-11-26 09:16:45          0      52428
#
#                                                 hashtags                   id  \
# 0                                                     []  1331236744767926275
# 1      [{'text': 'BlackFriday', 'indices': [51, 63]},...  1332009994905071618
# 2      [{'text': 'BlackFriday', 'indices': [14, 26]},...  1331855304699604992
# 3      [{'text': 'ofertas', 'indices': [52, 60]}, {'t...  1333126635239956481
# 4                                                     []  1333126089590321153
# ...                                                  ...                  ...
# 34505  [{'text': 'BlackFriday', 'indices': [30, 42]},...  1331892507764994050
# 34506  [{'text': 'ciberataque', 'indices': [51, 63]},...  1331892316920045571
# 34507  [{'text': 'BlackFriday', 'indices': [26, 38]},...  1331891158470037504
# 34508                                                 []  1331890809734651909
# 34509  [{'text': 'BlackFriday', 'indices': [26, 38]},...  1331889619357544448
#
#                  location        query  retweets  \
# 0      Guayaquil, Ecuador  CyberMonday        17
# 1                  España  CyberMonday        20
# 2                  España  CyberMonday        21
# 3                     NaN  CyberMonday         0
# 4               El Averno  CyberMonday         2
# ...                   ...          ...       ...
# 34505    Alicante, España  CyberMonday         0
# 34506     Madrid y México  CyberMonday         0
# 34507                 NaN  CyberMonday        21
# 34508           Salamanca  CyberMonday         0
# 34509              España  CyberMonday        21
#
#                                                     text  \
# 0      Cámara de Comercio de Guayaquil anuncia cuatro...
# 1      No seas tu el chollo de los ciberdelincuentes ...
# 2      ¡Buenos días! #BlackFriday, #CyberMonday, #Nav...
# 3      Las fechas navideñas ya están aquí, y con ella...
# 4      RT @0xWORD: Como todos los años, desde hoy a l...
# ...                                                  ...
# 34505  Black Friday 2020: comprar en #BlackFriday o e...
# 34506  ¿Puede ser tu ordenador la puerta de entrada d...
# 34507  RT @INCIBE: ¡Buenos días! #BlackFriday, #Cyber...
# 34508  Cuándo y qué es el Cyber Monday: el día más es...
# 34509  RT @INCIBE: ¡Buenos días! #BlackFriday, #Cyber...
#
#                                                      url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 34505  [{'url': 'https://t.co/wY05KTI92B', 'expanded_...
# 34506  [{'url': 'https://t.co/ZEtirGRgG8', 'expanded_...
# 34507                                                 []
# 34508  [{'url': 'https://t.co/DIoXIxXrKg', 'expanded_...
# 34509                                                 []
#
#                                                     urls             user
# 0      [{'url': 'https://t.co/m07aK2u47s', 'expanded_...    eluniversocom
# 1      [{'url': 'https://t.co/T2FzUbDGca', 'expanded_...           INCIBE
# 2      [{'url': 'https://t.co/nOUN4HJqfx', 'expanded_...           INCIBE
# 3      [{'url': 'https://t.co/MnHjVJEO3I', 'expanded_...         HogarCom
# 4                                                     []  InformDelAverno
# ...                                                  ...              ...
# 34505                                                NaN   informacion_es
# 34506                                                NaN        BOTECHFPI
# 34507                                                NaN      CDTLEntregu
# 34508                                                NaN    XavierMiolard
# 34509                                                NaN     osiseguridad
#
# [34510 rows x 13 columns]

# %%
count = 1
while count >= 1:
    tweets = tweepy.Cursor(api.search,
                           q=query,
                           lang='es',
                           geo='40.416775,-3.703790, 510',
                           result_type='mixed',
                           max_id=df.id.min()).items(1500)
    data = [[query, tweet.id, tweet.created_at, tweet.user.location, tweet.user.screen_name, tweet.text, tweet.entities['hashtags'], tweet.favorite_count, tweet.retweet_count, tweet.entities['urls'], tweet.user.followers_count] for tweet in tweets] 
    df2 = pd.DataFrame(data=data, columns=['query','id', 'date', 'location', 'user', 'text', 'hashtags', 'favorites', 'retweets', 'url', 'followers'])
    df = df.append(df2, sort=True)
    count += 1
    print('Updating your dataframe. Adding 1500 to the dataframe')
    print(df.shape)
    print('Id max', df.id.max())
# Out:
# Rate limit reached. Sleeping for: 341
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Rate limit reached. Sleeping for: 838
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Rate limit reached. Sleeping for: 841
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36778, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# ...
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Updating your dataframe. Adding 1500 to the dataframe
# (36779, 13)
# Id max 1333821483148333056
# Rate limit reached. Sleeping for: 842
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-69d71576ef75> in <module>
#       7                            result_type='mixed',
#       8                            max_id=df.id.min()).items(1500)
# ----> 9     data = [[query, tweet.id, tweet.created_at, tweet.user.location, tweet.user.screen_name, tweet.text, tweet.entities['hashtags'], tweet.favorite_count, tweet.retweet_count, tweet.entities['urls'], tweet.user.followers_count] for tweet in tweets]
#      10     df2 = pd.DataFrame(data=data, columns=['query','id', 'date', 'location', 'user', 'text', 'hashtags', 'favorites', 'retweets', 'url', 'followers'])
#      11     df = df.append(df2, sort=True)
#
# <ipython-input-24-69d71576ef75> in <listcomp>(.0)
#       7                            result_type='mixed',
#       8                            max_id=df.id.min()).items(1500)
# ----> 9     data = [[query, tweet.id, tweet.created_at, tweet.user.location, tweet.user.screen_name, tweet.text, tweet.entities['hashtags'], tweet.favorite_count, tweet.retweet_count, tweet.entities['urls'], tweet.user.followers_count] for tweet in tweets]
#      10     df2 = pd.DataFrame(data=data, columns=['query','id', 'date', 'location', 'user', 'text', 'hashtags', 'favorites', 'retweets', 'url', 'followers'])
#      11     df = df.append(df2, sort=True)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tweepy/binder.py in execute(self)
#     160                                     if self.wait_on_rate_limit_notify:
#     161                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 162                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     163
#     164                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %%
df.to_csv('../output/CyberMonday.csv')

# %%
df = pd.read_csv('../output/CyberMonday.csv')
df
# Out:
#        Unnamed: 0                 date  favorites  followers  \
# 0               0  2020-11-24 14:02:27         23    2208088
# 1               1  2020-11-26 17:15:04         22      61206
# 2               2  2020-11-26 07:00:23         22      61206
# 3               3  2020-11-29 19:12:12          0        358
# 4               4  2020-11-29 19:10:02          0        104
# ...           ...                  ...        ...        ...
# 34505        1495  2020-11-26 09:28:13          3     154743
# 34506        1496  2020-11-26 09:27:28          0        314
# 34507        1497  2020-11-26 09:22:52          0        167
# 34508        1498  2020-11-26 09:21:29          1        303
# 34509        1499  2020-11-26 09:16:45          0      52428
#
#                                                 hashtags                   id  \
# 0                                                     []  1331236744767926275
# 1      [{'text': 'BlackFriday', 'indices': [51, 63]},...  1332009994905071618
# 2      [{'text': 'BlackFriday', 'indices': [14, 26]},...  1331855304699604992
# 3      [{'text': 'ofertas', 'indices': [52, 60]}, {'t...  1333126635239956481
# 4                                                     []  1333126089590321153
# ...                                                  ...                  ...
# 34505  [{'text': 'BlackFriday', 'indices': [30, 42]},...  1331892507764994050
# 34506  [{'text': 'ciberataque', 'indices': [51, 63]},...  1331892316920045571
# 34507  [{'text': 'BlackFriday', 'indices': [26, 38]},...  1331891158470037504
# 34508                                                 []  1331890809734651909
# 34509  [{'text': 'BlackFriday', 'indices': [26, 38]},...  1331889619357544448
#
#                  location        query  retweets  \
# 0      Guayaquil, Ecuador  CyberMonday        17
# 1                  España  CyberMonday        20
# 2                  España  CyberMonday        21
# 3                     NaN  CyberMonday         0
# 4               El Averno  CyberMonday         2
# ...                   ...          ...       ...
# 34505    Alicante, España  CyberMonday         0
# 34506     Madrid y México  CyberMonday         0
# 34507                 NaN  CyberMonday        21
# 34508           Salamanca  CyberMonday         0
# 34509              España  CyberMonday        21
#
#                                                     text  \
# 0      Cámara de Comercio de Guayaquil anuncia cuatro...
# 1      No seas tu el chollo de los ciberdelincuentes ...
# 2      ¡Buenos días! #BlackFriday, #CyberMonday, #Nav...
# 3      Las fechas navideñas ya están aquí, y con ella...
# 4      RT @0xWORD: Como todos los años, desde hoy a l...
# ...                                                  ...
# 34505  Black Friday 2020: comprar en #BlackFriday o e...
# 34506  ¿Puede ser tu ordenador la puerta de entrada d...
# 34507  RT @INCIBE: ¡Buenos días! #BlackFriday, #Cyber...
# 34508  Cuándo y qué es el Cyber Monday: el día más es...
# 34509  RT @INCIBE: ¡Buenos días! #BlackFriday, #Cyber...
#
#                                                      url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 34505  [{'url': 'https://t.co/wY05KTI92B', 'expanded_...
# 34506  [{'url': 'https://t.co/ZEtirGRgG8', 'expanded_...
# 34507                                                 []
# 34508  [{'url': 'https://t.co/DIoXIxXrKg', 'expanded_...
# 34509                                                 []
#
#                                                     urls             user
# 0      [{'url': 'https://t.co/m07aK2u47s', 'expanded_...    eluniversocom
# 1      [{'url': 'https://t.co/T2FzUbDGca', 'expanded_...           INCIBE
# 2      [{'url': 'https://t.co/nOUN4HJqfx', 'expanded_...           INCIBE
# 3      [{'url': 'https://t.co/MnHjVJEO3I', 'expanded_...         HogarCom
# 4                                                     []  InformDelAverno
# ...                                                  ...              ...
# 34505                                                NaN   informacion_es
# 34506                                                NaN        BOTECHFPI
# 34507                                                NaN      CDTLEntregu
# 34508                                                NaN    XavierMiolard
# 34509                                                NaN     osiseguridad
#
# [34510 rows x 13 columns]

# %%
df.date.max()
# Out:
# '2020-11-29 19:12:12'
